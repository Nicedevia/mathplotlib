# %% [markdown]
# avec la fonction orienter obj

# %%
# pre requis
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3, 4]
y = [1, 4, 3, 8, 5]

# %% [markdown]
# les subplots sont dans ax qui n'est pas un objet mais un tableau numpy  qui contient different obj
# fig est un obj
# pour verrifier les type on untilise type(nom)

# %%
fig, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(x, y)
ax[1].plot(x, y, c='red')
plt.show()
